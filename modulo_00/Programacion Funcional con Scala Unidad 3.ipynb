// %% [markdown]
// # Unidad 3. Datos inmutables
// ## A modo de repaso
// ### ¿Qué es una función pura?Una función pura es una función que su salida depende únicamente de sus parámetros de entrada y su algoritmo produce su salida. Este no lee cualquier valor del "mundo exterior" y no modifica valor alguno del "mundo exterior".

// %%
def abs(a:Int):Int = ???
// Out:
// defined function abs
